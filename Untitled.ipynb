# %% [markdown]
# # Test

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import r2_score

# Importing the dataset
df = pd.read_csv('powerproduction.txt')
df = df.drop(df[(df.speed >= 0.325) & (df.power == 0.0)].index)

y = df.power.to_numpy() 
X = df.speed.to_numpy().reshape(-1, 1)

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

"""
# Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
"""

# Fitting Linear Regression to the dataset
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)

# Visualizing the Linear Regression results
def viz_linear():
    plt.scatter(X, y, color='red')
    plt.plot(X, lin_reg.predict(X), color='blue')
    plt.title('Truth or Bluff (Linear Regression)')
    plt.xlabel('Position level')
    plt.ylabel('Salary')
    plt.show()
    return
viz_linear()

# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)

# Visualizing the Polymonial Regression results
def viz_polymonial():
    plt.scatter(X, y, color='red')
    plt.plot(X, pol_reg.predict(poly_reg.fit_transform(X)), color='blue')
    plt.title('Truth or Bluff (Linear Regression)')
    plt.xlabel('Position level')
    plt.ylabel('Salary')
    plt.show()
    return
viz_polymonial()

# Additional feature
# Making the plot line (Blue one) more smooth
def viz_polymonial_smooth():
    X_grid = np.arange(min(X), max(X), 0.1)
    X_grid = X_grid.reshape(len(X_grid), 1) #Why do we need to reshape? (https://www.tutorialspoint.com/numpy/numpy_reshape.htm)
    # Visualizing the Polymonial Regression results
    plt.scatter(X, y, color='red')
    plt.plot(X_grid, pol_reg.predict(poly_reg.fit_transform(X_grid)), color='blue')
    plt.title('Truth or Bluff (Linear Regression)')
    plt.xlabel('Position level')
    plt.ylabel('Salary')
    plt.show()
    return
viz_polymonial_smooth()

# Predicting a new result with Linear Regression
lin_reg.predict([[5.5]])
#output should be 249500

# Predicting a new result with Polymonial Regression
pol_reg.predict(poly_reg.fit_transform([[5.5]]))
#output should be 132148.43750003

print(r2_score(y, poly_pred))
# Out:
# 0.9881894949408745

# %%
# https://www.analyticsvidhya.com/blog/2020/03/polynomial-regression-python/v

# Importing Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import r2_score
import seaborn as sns

# Importing the dataset
df = pd.read_csv('powerproduction.txt')

# Cleann the data
df = df.drop(df[(df.speed >= 0.325) & (df.power == 0.0)].index)

y = df.power.to_numpy() 
x = df.speed.to_numpy().reshape(-1, 1)

# Training Model
lm=LinearRegression()
lm.fit(x.reshape(-1,1),y.reshape(-1,1))

y_pred=lm.predict(x.reshape(-1,1))

# plotting predictions
plt.figure(figsize=(10,5))
plt.scatter(x,y,s=15)
plt.plot(x,y_pred,color='g')
plt.xlabel('Speed (m/s)',fontsize=16)
plt.ylabel('Power',fontsize=16)
plt.show()
print(f'Root mean squared error for Linear Regression=> {np.sqrt(mean_squared_error(y,y_pred))}')
print(r2_score(y, y_pred))

# Predictions
#y_pred_test=lm.predict([[7.708]])
#model = LinearRegression().fit(x, y)
#r_sq = model.score(X, y)
#print('coefficient of determination:', r_sq)
#print('intercept:', model.intercept_)
#print('slope:', model.coef_)

test=[[21.396]] # Actual answer 88.544 Returns 100.1198906
#test2=[[14.84]] # Actual answer 75.466 Returns 63.64461921
#test3=[[7.708]] # Actual answer 10.297 Returns 23.964687

###   y_pred_test = lm.predict([[test1]])   ###
#print('predicted response:', y_pred_test, sep='\n')

# Test refers to the wind power entered to prvide a predicted value. Emp refers to the empirical data from csv file received
test1, emp1 = 0.676, 7.974 
test2, emp2 = 5.180, 4.525 
test3, emp3 = 10.210, 20.704
test4, emp4 = 12.588, 54.079
test5, emp5 = 15.065, 73.911
test6, emp6 = 17.843, 91.270 
test7, emp7 = 21.396, 88.544 

def Accuracy (test, emp):
    if (((lm.predict([[test]]))/emp)*100 < 100):
        return f"Undershot by {100 - ((lm.predict([[test]]))/emp)*100}%"
    else:
        return f"Overshot by {(((lm.predict([[test]]))/emp) * 100) - 100}%"
   

print(f'\nTest 1-\nWind Speed: {test1} m/s\nEmpirical data: {emp1}\nPredicted  value: {(lm.predict([[test1]]))}\nActual Difference: {abs(emp1-lm.predict([[test1]]))}\nAccuracy: {Accuracy (test1, emp1)}')
print(f'\nTest 2-\nWind Speed: {test2} m/s\nEmpirical data: {emp2}\nPredicted  value: {(lm.predict([[test2]]))}\nActual Difference: {abs(emp2-lm.predict([[test1]]))}\nAccuracy: {Accuracy (test2, emp2)}')
print(f'\nTest 3-\nWind Speed: {test3} m/s\nEmpirical data: {emp3}\nPredicted  value: {(lm.predict([[test3]]))}\nActual Difference: {abs(emp3-lm.predict([[test1]]))}\nAccuracy: {Accuracy (test3, emp3)}')
print(f'\nTest 4-\nWind Speed: {test4} m/s\nEmpirical data: {emp4}\nPredicted  value: {(lm.predict([[test4]]))}\nActual Difference: {abs(emp4-lm.predict([[test1]]))}\nAccuracy: {Accuracy (test4, emp4)}')
print(f'\nTest 5-\nWind Speed: {test5} m/s\nEmpirical data: {emp5}\nPredicted  value: {(lm.predict([[test5]]))}\nActual Difference: {abs(emp5-lm.predict([[test1]]))}\nAccuracy: {Accuracy (test5, emp5)}')
print(f'\nTest 6-\nWind Speed: {test6} m/s\nEmpirical data: {emp6}\nPredicted  value: {(lm.predict([[test6]]))}\nActual Difference: {abs(emp6-lm.predict([[test1]]))}\nAccuracy: {Accuracy (test6, emp6)}')
print(f'\nTest 7-\nWind Speed: {test7} m/s\nEmpirical data: {emp7}\nPredicted  value: {(lm.predict([[test7]]))}\nActual Difference: {abs(emp7-lm.predict([[test1]]))}\nAccuracy: {Accuracy (test7, emp7)}')
# Out:
# Root mean squared error for Linear Regression=> 12.971479727702798
# 0.8980963337957819
#
# Test 1-
# Wind Speed: 0.676 m/s
# Empirical data: 7.974
# Predicted  value: [[-15.15888048]]
# Actual Difference: [[23.13288048]]
# Accuracy: Undershot by [[290.1038435]]%
#
# Test 2-
# Wind Speed: 5.18 m/s
# Empirical data: 4.525
# Predicted  value: [[9.89978675]]
# Actual Difference: [[19.68388048]]
# Accuracy: Overshot by [[118.77981761]]%
#
# Test 3-
# Wind Speed: 10.21 m/s
# Empirical data: 20.704
# Predicted  value: [[37.88493243]]
# Actual Difference: [[35.86288048]]
# Accuracy: Overshot by [[82.98363809]]%
#
# Test 4-
# Wind Speed: 12.588 m/s
# Empirical data: 54.079
# Predicted  value: [[51.1152856]]
# Actual Difference: [[69.23788048]]
# Accuracy: Undershot by [[5.48034247]]%
#
# Test 5-
# Wind Speed: 15.065 m/s
# Empirical data: 73.911
# Predicted  value: [[64.89643984]]
# Actual Difference: [[89.06988048]]
# Accuracy: Undershot by [[12.19650682]]%
#
# Test 6-
# Wind Speed: 17.843 m/s
# Empirical data: 91.27
# Predicted  value: [[80.35225191]]
# Actual Difference: [[106.42888048]]
# Accuracy: Undershot by [[11.96203362]]%
#
# Test 7-
# Wind Speed: 21.396 m/s
# Empirical data: 88.544
# Predicted  value: [[100.1198906]]
# Actual Difference: [[103.70288048]]
# Accuracy: Overshot by [[13.07360251]]%

# %%
# importing libraries for polynomial transform
from sklearn.preprocessing import PolynomialFeatures
# for creating pipeline
from sklearn.pipeline import Pipeline
# creating pipeline and fitting it on data
Input=[('polynomial',PolynomialFeatures(degree=5)),('modal',LinearRegression())]
pipe=Pipeline(Input)
pipe.fit(x.reshape(-1,1),y.reshape(-1,1))

poly_pred=pipe.predict(x.reshape(-1,1))
#sorting predicted values with respect to predictor
sorted_zip = sorted(zip(x,poly_pred))
x_poly, poly_pred = zip(*sorted_zip)
#plotting predictions
plt.figure(figsize=(10,6))
plt.scatter(x,y,s=15)
plt.plot(x,y_pred,color='g',label='Linear Regression')
plt.plot(x_poly,poly_pred,color='r',label='Polynomial Regression')
plt.xlabel('Predictor',fontsize=16)
plt.ylabel('Target',fontsize=16)
plt.legend()
plt.show()

print(f'Root mean squared error for Polynomial Regression=> {np.sqrt(mean_squared_error(y,poly_pred))}')
print(f'The R2 score is {r2_score(y, poly_pred)}')

# Test refers to the wind power entered to prvide a predicted value. Emp refers to the empirical data from csv file received
test1, emp1 = 0.676, 7.974 
test2, emp2 = 5.180, 4.525 
test3, emp3 = 10.210, 20.704
test4, emp4 = 12.588, 54.079
test5, emp5 = 15.065, 73.911
test6, emp6 = 17.843, 91.270 
test7, emp7 = 21.396, 88.544 

def Accuracy (test, emp):
    if ((pipe.predict([[test]])/emp)*100 < 100):
        return f"Undershot by {100 - (pipe.predict([[test]])/emp)*100}%"
    else:
        return f"Overshot by {((pipe.predict([[test]])/emp) * 100) - 100}%"

print(f'\nTest 1-\nWind Speed: {test1} m/s\nEmpirical data: {emp1}\nPredicted  value: {pipe.predict([[test1]])}\nActual Difference: {abs(emp1-pipe.predict([[test1]]))}\nAccuracy: {Accuracy (test1, emp1)}')
print(f'\nTest 2-\nWind Speed: {test2} m/s\nEmpirical data: {emp2}\nPredicted  value: {pipe.predict([[test2]])}\nActual Difference: {abs(emp2-pipe.predict([[test2]]))}\nAccuracy: {Accuracy (test2, emp2)}')
print(f'\nTest 3-\nWind Speed: {test3} m/s\nEmpirical data: {emp3}\nPredicted  value: {pipe.predict([[test3]])}\nActual Difference: {abs(emp3-pipe.predict([[test3]]))}\nAccuracy: {Accuracy (test3, emp3)}')
print(f'\nTest 4-\nWind Speed: {test4} m/s\nEmpirical data: {emp4}\nPredicted  value: {pipe.predict([[test4]])}\nActual Difference: {abs(emp4-pipe.predict([[test4]]))}\nAccuracy: {Accuracy (test4, emp4)}')
print(f'\nTest 5-\nWind Speed: {test5} m/s\nEmpirical data: {emp5}\nPredicted  value: {pipe.predict([[test5]])}\nActual Difference: {abs(emp5-pipe.predict([[test5]]))}\nAccuracy: {Accuracy (test5, emp5)}')
print(f'\nTest 6-\nWind Speed: {test6} m/s\nEmpirical data: {emp6}\nPredicted  value: {pipe.predict([[test6]])}\nActual Difference: {abs(emp6-pipe.predict([[test6]]))}\nAccuracy: {Accuracy (test6, emp6)}')
print(f'\nTest 7-\nWind Speed: {test7} m/s\nEmpirical data: {emp7}\nPredicted  value: {pipe.predict([[test7]])}\nActual Difference: {abs(emp7-pipe.predict([[test7]]))}\nAccuracy: {Accuracy (test7, emp7)}')
# Out:
# Root mean squared error for Polynomial Regression=> 4.4159978346386435
# The R2 score is 0.9881894949408745
#
# Test 1-
# Wind Speed: 0.676 m/s
# Empirical data: 7.974
# Predicted  value: [[3.26601037]]
# Actual Difference: [[4.70798963]]
# Accuracy: Undershot by [[59.04175612]]%
#
# Test 2-
# Wind Speed: 5.18 m/s
# Empirical data: 4.525
# Predicted  value: [[2.62959469]]
# Actual Difference: [[1.89540531]]
# Accuracy: Undershot by [[41.88741012]]%
#
# Test 3-
# Wind Speed: 10.21 m/s
# Empirical data: 20.704
# Predicted  value: [[23.90135325]]
# Actual Difference: [[3.19735325]]
# Accuracy: Overshot by [[15.44316679]]%
#
# Test 4-
# Wind Speed: 12.588 m/s
# Empirical data: 54.079
# Predicted  value: [[48.83606297]]
# Actual Difference: [[5.24293703]]
# Accuracy: Undershot by [[9.69495928]]%
#
# Test 5-
# Wind Speed: 15.065 m/s
# Empirical data: 73.911
# Predicted  value: [[75.44110728]]
# Actual Difference: [[1.53010728]]
# Accuracy: Overshot by [[2.07020238]]%
#
# Test 6-
# Wind Speed: 17.843 m/s
# Empirical data: 91.27
# Predicted  value: [[95.5893564]]
# Actual Difference: [[4.3193564]]
# Accuracy: Overshot by [[4.732504]]%
#
# Test 7-
# Wind Speed: 21.396 m/s
# Empirical data: 88.544
# Predicted  value: [[99.53673769]]
# Actual Difference: [[10.99273769]]
# Accuracy: Overshot by [[12.4150001]]%
